# %% [markdown]
# # Taichi Test Notebook
# Simple verification that Taichi is working properly

# %%
# %cd /workspaces/procedural-design-scratch/procedural-design
# !pip install -r requirements.txt
# Out:
# /workspaces/procedural-design-scratch/procedural-design
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 3.8 MB/s  0:00:14m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 56.2 MB/s  0:00:006m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 55.3 MB/s  0:00:006m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 736.5/736.5 kB 18.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 39.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 48.9 MB/s  0:00:00
# ...
#   Attempting uninstall: jupyterlab0m╸━━━━━━━━━━━━━━━  8/13 [taichi]ets]-py]
#     Found existing installation: jupyterlab 4.4.4━━━━━━━━━━━━━  8/13 [taichi]
#     Uninstalling jupyterlab-4.4.4:━━━━╸━━━━━━━━━ 10/13 [jupyterlab]
#       Successfully uninstalled jupyterlab-4.4.4╸━━━━━━━━━ 10/13 [jupyterlab]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/13 [jupyter]1/13 [notebook]b]
# ...

# %%
import taichi as ti
ti.init(arch=ti.cpu)

@ti.kernel
def hello_world():
    print("Hello from Taichi!")

hello_world()
# Out:
# [Taichi] version 1.7.4, llvm 15.0.4, commit b4b956fd, linux, python 3.12.1
# [I 11/04/25 23:10:28.869 35525] [shell.py:_shell_pop_print@23] Graphical python shell detected, using wrapped sys.stdout
# [Taichi] Starting on arch=x64
# Hello from Taichi!
